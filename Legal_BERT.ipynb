# %%
# !pip install -q transformers datasets torch scikit-learn pandas numpy

# %%
import re
import numpy as np
import pandas as pd
import torch

from datasets import load_dataset, Dataset
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer
)

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
dataset = load_dataset(
    "json",
    data_files="CUAD_v1.json",
    field="data"
)

dataset
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 510
#     })
# })

# %%
samples = []

for contract in dataset["train"]:
    for para in contract["paragraphs"]:
        context = para["context"]

        for qa in para["qas"]:
            question = qa["question"]

            for ans in qa["answers"]:
                text = ans["text"].strip()
                if text:
                    samples.append({
                        "text": text,
                        "question": question
                    })

df = pd.DataFrame(samples)
df.head()
# Out:
#                                text  \
# 0             DISTRIBUTOR AGREEMENT
# 1                       Distributor
# 2               Electric City Corp.
# 3  Electric City of Illinois L.L.C.
# 4                           Company
#
#                                             question
# 0  Highlight the parts (if any) of this contract ...
# 1  Highlight the parts (if any) of this contract ...
# 2  Highlight the parts (if any) of this contract ...
# 3  Highlight the parts (if any) of this contract ...
# 4  Highlight the parts (if any) of this contract ...

# %%
def extract_clause(question):
    match = re.search(r'"([^"]+)"', question)
    return match.group(1) if match else None

df["clause_type"] = df["question"].apply(extract_clause)

# %%
CLAUSE_TYPES = ["Document Name", "Parties", "Agreement Date"
"Effective Date", "Expiration Date", "Renewal Term", "Notice Period to Terminate Renewal",
"Governing Law", "Most Favored Nation", "Non-Compete", "Exclusivity", "No-Solicit of Customers",
"Competitive Restriction Exception", "No-Solicit of Employees","Non-Disparagement", "Termination for Convenience",
"Rofr/Rofo/Rofn", "Change of Control", "Anti-Assignment", "Revenue/Profit Sharing", "Price Restrictions",
"Minimum Commitment", "Volume Restriction", "IP Ownership Assignment", "Joint IP Ownership", "License Grant"
,"Non-Transferable License", "Affiliate License-Licensor", "Affiliate License-Licensee"
,"Unlimited/All-You-Can-Eat-License", "Irrevocable or Perpetual License", "Source Code Escrow", "Post-Termination Services"
,"Audit Rights", "Uncapped Liability", "Cap on Liability", "Liquidated Damages", "Warranty Duration"
,"Insurance", "Covenant Not to Sue", "Third Party Beneficiary"]

# %%
print(df["clause_type"].tolist())
# Out:
# ['Document Name', 'Parties', 'Parties', 'Parties', 'Parties', 'Parties', 'Agreement Date', 'Effective Date', 'Effective Date', 'Expiration Date', 'Renewal Term', 'Governing Law', 'Exclusivity', 'Exclusivity', 'Exclusivity', 'No-Solicit Of Customers', 'No-Solicit Of Customers', 'No-Solicit Of Employees', 'Rofr/Rofo/Rofn', 'Rofr/Rofo/Rofn', 'Rofr/Rofo/Rofn', 'Anti-Assignment', 'Anti-Assignment', 'Price Restrictions', 'Price Restrictions', 'Minimum Commitment', 'Minimum Commitment', 'Minimum Commitment', 'Minimum Commitment', 'Minimum Commitment', 'License Grant', 'License Grant', 'Post-Termination Services', 'Post-Termination Services', 'Post-Termination Services', 'Post-Termination Services', 'Warranty Duration', 'Warranty Duration', 'Warranty Duration', 'Warranty Duration', 'Warranty Duration', 'Warranty Duration', 'Warranty Duration', 'Warranty Duration', 'Insurance', 'Covenant Not To Sue', 'Document Name', 'Parties', 'Parties', 'Parties', 'Parties', 'Effective Date', 'Expiration Date', 'Expiration Date', 'Governing Law', 'Change Of Control', 'Change Of Control', 'Change Of Control', 'Change Of Control', 'Anti-Assignment', 'License Grant', 'License Grant', 'Audit Rights', 'Uncapped Liability', 'Uncapped Liability', 'Uncapped Liability', 'Uncapped Liability', 'Uncapped Liability', 'Cap On Liability', 'Cap On Liability', 'Cap On Liability', 'Cap On Liability', 'Warranty Duration', 'Document Name', 'Parties', 'Parties', 'Expiration Date', 'Governing Law', 'Warranty Duration', 'Insurance', 'Document Name', 'Parties', 'Parties', 'Parties', 'Parties', 'Parties', 'Parties', 'Agreement Date', 'Effective Date', 'Expiration Date', 'Renewal Term', 'Renewal Term', 'Notice Period To Terminate Renewal', 'Notice Period To Terminate Renewal', 'Governing Law', 'Termination For Convenience', 'Cap On Liability', 'Document Name', 'Parties', 'Parties', 'Agreement Date', 'Document Name', 'Parties', 'Parties', 'Parties', 'Parties', 'Agreement Date', 'Effective Date', 'Expiration Date', 'Governing Law', 'Non-Compete', 'Exclusivity', 'Exclusivity', 'Exclusivity', 'Competitive Restriction Exception', 'Competitive Restriction Exception', 'Competitive Restriction Exception', 'Competitive Restriction Exception', 'Anti-Assignment', 'Minimum Commitment', 'Minimum Commitment', 'Minimum Commitment', 'Volume Restriction', 'License Grant', 'Document Name', 'Parties', 'Parties', 'Parties', 'Parties', 'Agreement Date', 'Effective Date', 'Expiration Date', 'Governing Law', 'Non-Compete', 'Non-Compete', 'Non-Compete', 'Non-Compete', 'Termination For Convenience', 'Anti-Assignment', 'Anti-Assignment', 'Volume Restriction', 'Ip Ownership Assignment', 'Ip Ownership Assignment', 'Ip Ownership Assignment', 'Ip Ownership Assignment', 'License Grant', 'Irrevocable Or Perpetual License', 'Post-Termination Services', 'Document Name', 'Parties', 'Parties', 'Parties', 'Parties', 'Parties', 'Parties', 'Parties', 'Parties', 'Parties', 'Parties', 'Agreement Date', 'Effective Date', 'Effective Date', 'Expiration Date', 'Governing Law', 'Document Name', 'Parties', 'Parties', 'Parties', 'Parties', 'Parties', 'Agreement Date', 'Effective Date', 'Effective Date', 'Expiration Date', 'Governing Law', 'Non-Compete', 'Exclusivity', 'Competitive Restriction Exception', 'Competitive Restriction Exception', 'No-Solicit Of Employees', 'Termination For Convenience', 'Change Of Control', 'Anti-Assignment', 'Anti-Assignment', 'Anti-Assignment', 'Anti-Assignment', 'Revenue/Profit Sharing', 'Revenue/Profit Sharing', 'Revenue/Profit Sharing', 'Minimum Commitment', 'Minimum Commitment', 'Minimum Commitment', 'Minimum Commitment', 'Minimum Commitment', 'Ip Ownership Assignment', 'Ip Ownership Assignment', 'Ip Ownership Assignment', 'License Grant', 'License Grant', 'License Grant', 'Non-Transferable License', 'Non-Transferable License', 'Affiliate License-Licensee', 'Audit Rights', 'Audit Rights', 'Audit Rights', 'Audit Rights', 'Audit Rights', 'Uncapped Liability', 'Cap On Liability', 'Cap On Liab ...

# %%
df.shape
# Out:
# (13823, 3)

# %%
df = df[df["clause_type"].isin(CLAUSE_TYPES)]
df.shape
# Out:
# (10687, 3)

# %%
df["labels"] = df["clause_type"].apply(lambda x: [x])

# %%
print(df["labels"].tolist())
# Out:
# [['Document Name'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Expiration Date'], ['Renewal Term'], ['Governing Law'], ['Exclusivity'], ['Exclusivity'], ['Exclusivity'], ['Rofr/Rofo/Rofn'], ['Rofr/Rofo/Rofn'], ['Rofr/Rofo/Rofn'], ['Anti-Assignment'], ['Anti-Assignment'], ['Price Restrictions'], ['Price Restrictions'], ['Minimum Commitment'], ['Minimum Commitment'], ['Minimum Commitment'], ['Minimum Commitment'], ['Minimum Commitment'], ['License Grant'], ['License Grant'], ['Post-Termination Services'], ['Post-Termination Services'], ['Post-Termination Services'], ['Post-Termination Services'], ['Warranty Duration'], ['Warranty Duration'], ['Warranty Duration'], ['Warranty Duration'], ['Warranty Duration'], ['Warranty Duration'], ['Warranty Duration'], ['Warranty Duration'], ['Insurance'], ['Document Name'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Expiration Date'], ['Expiration Date'], ['Governing Law'], ['Anti-Assignment'], ['License Grant'], ['License Grant'], ['Audit Rights'], ['Uncapped Liability'], ['Uncapped Liability'], ['Uncapped Liability'], ['Uncapped Liability'], ['Uncapped Liability'], ['Warranty Duration'], ['Document Name'], ['Parties'], ['Parties'], ['Expiration Date'], ['Governing Law'], ['Warranty Duration'], ['Insurance'], ['Document Name'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Expiration Date'], ['Renewal Term'], ['Renewal Term'], ['Governing Law'], ['Document Name'], ['Parties'], ['Parties'], ['Document Name'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Expiration Date'], ['Governing Law'], ['Non-Compete'], ['Exclusivity'], ['Exclusivity'], ['Exclusivity'], ['Competitive Restriction Exception'], ['Competitive Restriction Exception'], ['Competitive Restriction Exception'], ['Competitive Restriction Exception'], ['Anti-Assignment'], ['Minimum Commitment'], ['Minimum Commitment'], ['Minimum Commitment'], ['Volume Restriction'], ['License Grant'], ['Document Name'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Expiration Date'], ['Governing Law'], ['Non-Compete'], ['Non-Compete'], ['Non-Compete'], ['Non-Compete'], ['Anti-Assignment'], ['Anti-Assignment'], ['Volume Restriction'], ['License Grant'], ['Post-Termination Services'], ['Document Name'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Expiration Date'], ['Governing Law'], ['Document Name'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Expiration Date'], ['Governing Law'], ['Non-Compete'], ['Exclusivity'], ['Competitive Restriction Exception'], ['Competitive Restriction Exception'], ['Anti-Assignment'], ['Anti-Assignment'], ['Anti-Assignment'], ['Anti-Assignment'], ['Revenue/Profit Sharing'], ['Revenue/Profit Sharing'], ['Revenue/Profit Sharing'], ['Minimum Commitment'], ['Minimum Commitment'], ['Minimum Commitment'], ['Minimum Commitment'], ['Minimum Commitment'], ['License Grant'], ['License Grant'], ['License Grant'], ['Non-Transferable License'], ['Non-Transferable License'], ['Affiliate License-Licensee'], ['Audit Rights'], ['Audit Rights'], ['Audit Rights'], ['Audit Rights'], ['Audit Rights'], ['Uncapped Liability'], ['Liquidated Damages'], ['Insurance'], ['Document Name'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Parties'], ['Expiration Date'], ['Renewal Term'], ['Governing Law'], ['Non-Compete'], ['Non-Compete'], ['Exclusivity'], ['Exclusivity'], ['Exclusivity'], ['Anti-Assignment'], ['Anti-Assignment'], ['Revenue/Profit Sharing'], ['License Grant'], ['License Grant'], ['License Grant'], ['License Grant'], ['License Grant'], ['License Grant'], ['License Grant'], ['License Grant'], ['Non-Transferable License'], ['Non-Transferable License'], ['Post-Termination Services'], ['Post-Termination Services'], ['Post-Termination Services'], ['Post-Termination Services'], ['Post-Termination Services'], ['Post-Termination Services'], ['Post ...

# %%
mlb = MultiLabelBinarizer(classes=CLAUSE_TYPES)
y = mlb.fit_transform(df["labels"])

print(y.shape)  # (num_samples, 41)
# Out:
# (10687, 40)

# %%
(y.sum(axis=1) > 0).mean()
# Out:
# np.float64(1.0)

# %%
hf_dataset = Dataset.from_dict({
    "text": df["text"].tolist(),
    "labels": y.astype(float).tolist()
})

hf_dataset
# Out:
# Dataset({
#     features: ['text', 'labels'],
#     num_rows: 10687
# })

# %%
tokenizer = AutoTokenizer.from_pretrained(
    "nlpaueb/legal-bert-base-uncased"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
def tokenize(batch):
    return tokenizer(
        batch["text"],
        padding="max_length",
        truncation=True,
        max_length=512
    )

hf_dataset = hf_dataset.map(tokenize, batched=True)
hf_dataset = hf_dataset.remove_columns(["text"])
hf_dataset = hf_dataset.map(
    lambda x: {"labels": torch.tensor(x["labels"], dtype=torch.float)}
)

hf_dataset.set_format(type="torch")
# Out:
# Map:   0%|          | 0/10687 [00:00<?, ? examples/s]
# Map:   0%|          | 0/10687 [00:00<?, ? examples/s]

# %%
dataset_split = hf_dataset.train_test_split(test_size=0.1)
train_ds = dataset_split["train"]
val_ds = dataset_split["test"]

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    "nlpaueb/legal-bert-base-uncased",
    num_labels=len(CLAUSE_TYPES),
    problem_type="multi_label_classification"
)
# Out:
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at nlpaueb/legal-bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="./legal-bert-cuad",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=5,
    weight_decay=0.01,
    logging_steps=100,
    load_best_model_at_end=True
)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    probs = torch.sigmoid(torch.tensor(logits))
    preds = (probs > 0.5).int().numpy()

    return {
        "micro_f1": f1_score(labels, preds, average="micro"),
        "macro_f1": f1_score(labels, preds, average="macro"),
        "precision": precision_score(labels, preds, average="micro"),
        "recall": recall_score(labels, preds, average="micro")
    }

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# /tmp/ipython-input-4015516837.py:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
trainer.train()
# Out:
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None}.
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  3
# wandb: You chose "Don't visualize my results"
# Tracking run with wandb version 0.23.1
# W&B syncing is set to <code>`offline`<code> in this directory. Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.<br>Run data is saved locally in <code>/content/wandb/offline-run-20251218_102250-jfgiw64w</code>
#     <div>
#
#       <progress value='6015' max='6015' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6015/6015 1:16:40, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Micro F1</th>
#       <th>Macro F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.050100</td>
#       <td>0.047102</td>
#       <td>0.679245</td>
#       <td>0.186361</td>
#       <td>0.972125</td>
#       <td>0.521983</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.029200</td>
#       <td>0.029068</td>
#       <td>0.840874</td>
#       <td>0.361371</td>
#       <td>0.920935</td>
#       <td>0.773620</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.022900</td>
#       <td>0.024962</td>
#       <td>0.845309</td>
#       <td>0.397758</td>
#       <td>0.905882</td>
#       <td>0.792329</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.018000</td>
#       <td>0.022965</td>
#       <td>0.853767</td>
#       <td>0.467348</td>
#       <td>0.901247</td>
#       <td>0.811038</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.017300</td>
#       <td>0.022206</td>
#       <td>0.853333</td>
#       <td>0.473992</td>
#       <td>0.903766</td>
#       <td>0.808232</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# TrainOutput(global_step=6015, training_loss=0.04077081423893831, metrics={'train_runtime': 4615.3882, 'train_samples_per_second': 10.419, 'train_steps_per_second': 1.303, 'total_flos': 1.265732769079296e+16, 'train_loss': 0.04077081423893831, 'epoch': 5.0})

# %%
text = "This agreement shall be governed by the laws of India."

inputs = tokenizer(text, return_tensors="pt", truncation=True)
outputs = model(**inputs.to(model.device))

preds = (torch.sigmoid(outputs.logits) > 0.5).squeeze()

predicted_clauses = [
    CLAUSE_TYPES[i] for i, val in enumerate(preds) if val
]

predicted_clauses
# Out:
# ['Governing Law']

# %%
SAVE_DIR = "/content/legal-bert-cuad-finetuned"

trainer.save_model(SAVE_DIR)
tokenizer.save_pretrained(SAVE_DIR)
# Out:
# ('/content/legal-bert-cuad-finetuned/tokenizer_config.json',
#  '/content/legal-bert-cuad-finetuned/special_tokens_map.json',
#  '/content/legal-bert-cuad-finetuned/vocab.txt',
#  '/content/legal-bert-cuad-finetuned/added_tokens.json',
#  '/content/legal-bert-cuad-finetuned/tokenizer.json')

# %%
SAVE_DIR = "/content/drive/MyDrive/models/legal-bert-cuad-finetuned"

# %%
import os
os.makedirs(SAVE_DIR, exist_ok=True)

# %%
trainer.save_model(SAVE_DIR)
tokenizer.save_pretrained(SAVE_DIR)
# Out:
# ('/content/drive/MyDrive/models/legal-bert-cuad-finetuned/tokenizer_config.json',
#  '/content/drive/MyDrive/models/legal-bert-cuad-finetuned/special_tokens_map.json',
#  '/content/drive/MyDrive/models/legal-bert-cuad-finetuned/vocab.txt',
#  '/content/drive/MyDrive/models/legal-bert-cuad-finetuned/added_tokens.json',
#  '/content/drive/MyDrive/models/legal-bert-cuad-finetuned/tokenizer.json')

# %%
import joblib
joblib.dump(mlb, f"{SAVE_DIR}/label_binarizer.pkl")
# Out:
# ['/content/drive/MyDrive/models/legal-bert-cuad-finetuned/label_binarizer.pkl']

# %%
import json

# %%
SAVE_DIR = "/content/drive/MyDrive/models/legal-bert-cuad-finetuned"

# %%
tokenizer = AutoTokenizer.from_pretrained(SAVE_DIR)
model = AutoModelForSequenceClassification.from_pretrained(SAVE_DIR)
model.eval()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=40, bias=True)
# )

# %%
id2label = model.config.id2label

# %%
def predict(text):
  inputs = tokenizer(
      text,
      return_tensors="pt",
      truncation=True,
      max_length=256
  )

  with torch.no_grad():
    outputs = model(**inputs)

  probs = torch.softmax(outputs.logits, dim = 1)
  confidence, pred = torch.max(probs, dim = 1)

  return id2label[pred.item()], round(confidence.item(), 3)

# %%
with open("/content/manual-cluases.json") as f:
    clauses = json.load(f)

results = []

for c in clauses:
    predicted, confidence = predict(c["text"])
    label_idx = int(predicted.replace("LABEL_", ""))
    predicted = CLAUSE_TYPES[label_idx]
    results.append({
        "text": c["text"],
        "expected": c["expected_label"],
        "predicted": predicted,
        "confidence": confidence,
        "correct": predicted == c["expected_label"]
    })

# %%
count = 0
for r in results:
    print("-" * 80)
    print(f"Clause: {r['text']}")
    print(f"Expected : {r['expected']}")
    print(f"Predicted: {r['predicted']} (confidence={r['confidence']})")
    print(f"Correct  : {r['correct']}")
    if r["correct"]:
        count += 1

print(f"Accuracy: {count / len(results)}")
# Out:
# --------------------------------------------------------------------------------
# Clause: This Master Services Agreement ("Agreement") sets forth the terms governing the services described herein.
# Expected : Document Name
# Predicted: Document Name (confidence=0.787)
# Correct  : True
# --------------------------------------------------------------------------------
# Clause: This Agreement is entered into between Alpha Technologies Pvt. Ltd. and Beta Solutions LLP.
# Expected : Parties
# Predicted: Parties (confidence=0.998)
# Correct  : True
# --------------------------------------------------------------------------------
# Clause: This Agreement is made and entered into on the 10th day of January, 2024.
# Expected : Agreement Date
# Predicted: Expiration Date (confidence=0.969)
# Correct  : False
# --------------------------------------------------------------------------------
# Clause: The obligations under this Agreement shall commence on the Effective Date of February 1, 2024.
# Expected : Effective Date
# Predicted: Expiration Date (confidence=0.987)
# Correct  : False
# --------------------------------------------------------------------------------
# Clause: This Agreement shall expire on January 31, 2026, unless terminated earlier in accordance with its terms.
# Expected : Expiration Date
# Predicted: Expiration Date (confidence=0.987)
# Correct  : True
# --------------------------------------------------------------------------------
# Clause: Upon expiration, this Agreement shall automatically renew for successive one-year terms.
# Expected : Renewal Term
# Predicted: Renewal Term (confidence=0.932)
# Correct  : True
# --------------------------------------------------------------------------------
# Clause: Either party may prevent renewal by providing at least sixty (60) days’ written notice prior to expiration.
# Expected : Notice Period to Terminate Renewal
# Predicted: Renewal Term (confidence=0.936)
# Correct  : False
# --------------------------------------------------------------------------------
# Clause: This Agreement shall be governed by and construed in accordance with the laws of the State of New York.
# Expected : Governing Law
# Predicted: Governing Law (confidence=0.993)
# Correct  : True
# --------------------------------------------------------------------------------
# Clause: The pricing terms offered to the Client shall be no less favorable than those offered to any third party.
# Expected : Most Favored Nation
# Predicted: Rofr/Rofo/Rofn (confidence=0.144)
# Correct  : False
# --------------------------------------------------------------------------------
# Clause: During the term of this Agreement, the Contractor shall not engage in any business that competes with the Company.
# Expected : Non-Compete
# Predicted: Non-Compete (confidence=0.925)
# Correct  : True
# --------------------------------------------------------------------------------
# Clause: The Client agrees to appoint the Service Provider as its exclusive supplier for the duration of this Agreement.
# Expected : Exclusivity
# Predicted: Exclusivity (confidence=0.922)
# Correct  : True
# --------------------------------------------------------------------------------
# Clause: The Service Provider shall not solicit any customers of the Client during the term of this Agreement.
# Expected : No-Solicit of Customers
# Predicted: Exclusivity (confidence=0.55)
# Correct  : False
# --------------------------------------------------------------------------------
# Clause: The non-compete obligations shall not apply to activities conducted prior to the Effective Date.
# Expected : Competitive Restriction Exception
# Predicted: Non-Compete (confidence=0.483)
# Correct  : False
# --------------------------------------------------------------------------------
# Clause: Neither party shall solicit or hire employees of the other party during the term and for one year thereafter.
# Expected : No-Solicit of Employees
# Predicted: Non-Compete (confidence=0.873)
# Correct  : False
# --------------------------------------------------------------------------------
# Clause: The parties agree that neither shall make any disparaging statements regarding the other.
# Expected : Non-Disparagement
# Predicted: Non-Disparagement (confidence=0.789)
# Correct  : True
# --------------------------------------------------------------------------------
# Clause: Either party may terminate this Agreement for convenience upon thirty (30) days’ written notice.
# Expected : Termination for Convenience
# Predicted: Minimum Commitment (confidence=0.316)
# Correct  : False
# --------------------------------------------------------------------------------
# Clause: The Investor shall have a right of first refusal with respect to any proposed transfer of shares.
# Expected : Rofr/Rofo/Rofn
# Predicted: Rofr/Rofo/Rofn (confidence=0.978)
# Correct  : True
# --------------------------------------------------------------------------------
# Clause: In the event of a change of control, the Company shall provide written notice to the other party.
# Expected : Change of Control
# Predicted: Anti-Assignment (confidence=0.991)
# Correct  : False
# --------------------------------------------------------------------------------
# Clause: Neither party may assign this Agreement without the prior written consent of the other party.
# Expected : Anti-Assignment
# Predicted: Anti-Assignment (confidence=0.993)
# Correct  : True
# --------------------------------------------------------------------------------
# Clause: The parties shall share net profits generated from the jointly developed product in equal proportions.
# Expected : Revenue/Profit Sharing
# Predicted: Revenue/Profit Sharing (confidence=0.984)
# Correct  : True
# --------------------------------------------------------------------------------
# Clause: The license granted herein shall be non-transferable and may not be sublicensed without consent.
# Expected : Non-Transferable License
# Predicted: Anti-Assignment (confidence=0.558)
# Correct  : False
# --------------------------------------------------------------------------------
# Clause: All intellectual property developed under this Agreement shall be solely owned by the Company.
# Expected : IP Ownership Assignment
# Predicted: License Grant (confidence=0.672)
# Correct  : False
# --------------------------------------------------------------------------------
# Clause: The liability of the Service Provider under this Agreement shall not be capped in any manner.
# Expected : Uncapped Liability
# Predicted: Uncapped Liability (confidence=0.948)
# Correct  : True
# --------------------------------------------------------------------------------
# Clause: The total liability of either party under this Agreement shall not exceed the fees paid in the preceding twelve months.
# Expected : Cap on Liability
# Predicted: Uncapped Liability (confidence=0.947)
# Correct  : False
# --------------------------------------------------------------------------------
# Clause: Nothing in this Agreement shall be deemed to create any third-party beneficiary rights.
# Expected : Third Party Beneficiary
# Predicted: Third Party Beneficiary (confidence=0.539)
# Correct  : True
# Accuracy: 0.52
